# %% [markdown]
# # INSIDERGUARD AI - Dataset Exploration
# Synthetic demonstration data only.

# %%
import pandas as pd
import matplotlib.pyplot as plt

_df = pd.read_csv('../data/behavioural_demo.csv')
_df.head()

# %%
_df.describe()

# %%
_df['insider_risk'].value_counts().sort_index().plot(kind='bar')
plt.title('Demo class distribution')
plt.xlabel('Class')
plt.ylabel('Records')
plt.show()
